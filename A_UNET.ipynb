#   inflating: archive/OUHANDS_train/train/negative_data/depth/3190.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3191.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3192.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3193.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3194.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3195.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3196.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3197.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3198.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3199.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3200.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3201.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3202.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3203.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3204.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3205.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3206.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3207.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3208.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3209.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3210.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3211.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3212.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3213.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3214.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3215.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3216.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3217.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3218.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3219.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3220.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3221.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3222.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3223.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3224.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3225.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3226.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3227.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3228.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3229.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3230.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3231.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3232.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3233.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3234.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3235.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3236.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3237.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3238.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3239.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3240.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3241.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3242.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3243.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3244.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3245.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3246.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3247.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3248.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3249.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3250.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3251.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3252.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3253.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3254.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3255.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3256.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3257.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3258.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3259.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3260.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3261.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3262.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3263.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3264.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3265.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3266.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3267.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3268.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3269.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3270.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3271.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3272.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3273.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3274.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3275.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3276.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3277.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3278.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3279.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3280.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3281.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3282.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3283.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3284.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3285.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3286.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3287.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3288.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3289.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3290.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3291.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3292.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3293.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3294.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3295.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3296.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3297.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3298.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3299.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3300.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3301.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3302.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3303.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3304.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3305.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3306.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3307.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3308.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3309.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3310.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3311.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3312.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3313.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3314.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3315.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3316.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3317.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3318.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3319.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3320.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3321.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3322.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3323.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3324.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3325.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3326.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3327.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3328.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3329.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3330.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3331.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3332.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3333.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3334.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3335.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3336.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3337.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3338.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3339.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3340.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3341.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3342.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3343.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3344.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3345.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3346.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3347.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3348.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3349.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3350.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3351.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3352.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3353.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3354.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3355.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3356.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3357.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3358.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3359.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3360.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3361.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3362.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3363.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3364.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3365.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3366.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3367.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3368.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3369.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3370.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3371.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3372.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3373.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3374.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3375.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3376.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3377.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3378.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3379.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3380.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3381.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3382.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3383.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3384.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3385.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3386.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3387.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3388.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3389.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3390.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3391.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3392.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3393.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3394.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3395.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3396.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3397.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3398.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3399.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3400.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3401.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3402.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3403.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3404.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3405.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3406.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3407.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3408.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3409.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3410.png
#   inflating: archive/OUHANDS_train/train/negative_data/depth/3411.png

# %% [markdown]
# **DATA** **LOADER**

# %%
IMG_WIDTH = 320
IMG_HEIGHT = 320
IMG_CHANNELS = 3

# %%
path = '/content/archive/OUHANDS_train/train/hand_data/colour'

maskpath ='/content/archive/OUHANDS_train/train/hand_data/segmentation'

X_train = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_train = np.zeros((len(os.listdir(maskpath)), IMG_HEIGHT, IMG_WIDTH,1))

print('creating input data')
n=0
for name in tqdm(os.listdir(path)):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    X_train[n]=img
    n+=1

m=0
for name in tqdm(os.listdir(maskpath)):
    newmaskpath = os.path.join(maskpath,name)
    mpg=cv2.imread(newmaskpath,0)
    mpg=cv2.resize(mpg,(IMG_WIDTH,IMG_HEIGHT))
    mpg=np.expand_dims(mpg,axis=-1)
    Y_train[m]=mpg/255
    m+=1
# Out:
# creating input data
# 100%|██████████| 2000/2000 [01:12<00:00, 27.68it/s]
# 100%|██████████| 2000/2000 [01:41<00:00, 19.63it/s]

# %%
from sklearn.model_selection import StratifiedKFold

# %%
X_train.shape
# Out:
# (2000, 320, 320, 3)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

# %%
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
x = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

# %%
def conv_block(x, filter_size, size, dropout=0.1, batch_norm=True):
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv

# %%
def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape 
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

# %%
def gating_signal(input, out_size, batch_norm=False):
    """
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

# %%
def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %%
def Attention_UNet(input_shape, NUM_CLASSES=1, dropout_rate=0.1, batch_norm=True):
    '''
    Attention UNet, 
    
    '''
    # network structure
    FILTER_NUM = 64 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    
    inputs = layers.Input(input_shape, dtype=tf.float32)

    # Downsampling layers
    # DownRes 1, convolution + pooling
    conv_128 = conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model integration
    
    model = tf.keras.Model(inputs=[inputs], outputs=[conv_final])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
#Model Checkpoint
checkpoint_path_recog = "/content/drive/MyDrive/OUHANDS/A-Unet/checkp.ckpt"
model_checkpoint_recog = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path_recog,
                                                 save_weights_only=True,
                                                  monitor='val_accuracy',save_best_only=True,
                                                 verbose=1)

# %%
model = Attention_UNet(input_shape, 1, 0.1, True)

# %%
OUTPUT = model.fit(X_train,Y_train,validation_split = 0.1,batch_size=8,epochs=1,callbacks=[model_checkpoint_recog])
